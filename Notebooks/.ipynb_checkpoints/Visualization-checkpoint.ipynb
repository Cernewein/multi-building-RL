# %%
import pickle as pkl
import matplotlib.pyplot as plt
from matplotlib import style
import os 
os.chdir(os.path.dirname(os.getcwd()))
import pandas as pd
import pickle as pkl
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
style.use('ggplot')
# %matplotlib inline
import numpy as np

# %%
data = pkl.load(open('data/output/Multi_eval.pkl', "rb"))

# %%
data['Total Load'] = data['Total Load']*1000
data['Base Loads 1'] = data['Base Loads 1']*1000
data['Base Loads 2'] = data['Base Loads 2']*1000
data['Base Loads'] = data['Base Loads 1'] + data['Base Loads 2']

# %%
f, ax = plt.subplots(figsize=(15,7))
data['Base Loads'].plot()

# %%
data['Base Loads'].loc[data['Base Loads'] <= 2]
# Out:
# 0      1.983668
# 2      1.957991
# 4      1.639438
# 5      1.727090
# 6      1.726854
#          ...
# 650    1.994666
# 651    1.868233
# 700    1.941165
# 722    1.968477
# 724    1.873325
# Name: Base Loads, Length: 130, dtype: float64

# %%
data
# Out:
#      Inside Temperatures 1  Inside Temperatures 2  Base Loads 1  Base Loads 2  \
# 0                21.000000              21.000000      1.098315      0.885353
# 1                19.275664              19.275664      1.017038      0.994475
# 2                20.360825              20.360825      0.985877      0.972115
# 3                18.713671              18.713671      1.119113      0.948734
# 4                19.879680              19.879680      0.857257      0.782180
# ..                     ...                    ...           ...           ...
# 740              18.628853              18.628853      1.334992      1.183115
# 741              19.041405              19.041405      1.319931      1.178028
# 742              19.412535              19.412535      1.179588      1.256546
# 743              19.756667              19.756667      1.084692      1.117570
# 744              17.726616              17.726616      1.051942      1.045885
#
#      Ambient Temperatures  Actions    Rewards   Total Load
# 0                   2.118      0.0   0.000000  1952.291564
# 1                   2.118      6.0  -0.029284  1952.291564
# 2                   2.147      6.0  -2.339292  6011.512882
# 3                   2.324      8.0  -0.039160  1957.991434
# 4                   2.344      6.0  -7.988227  6067.847399
# ..                    ...      ...        ...          ...
# 740                -2.605      8.0 -14.112219  7011.932454
# 741                -2.735      8.0  -9.100884  6518.107154
# 742                -2.760      8.0  -4.964888  6497.958669
# 743                -2.714      8.0  -1.221437  6436.133091
# 744                -2.473      8.0  -0.044045  2202.261365
#
# [745 rows x 8 columns]

# %%
data['Rewards'].sum()
# Out:
# -4094.719353364741

# %%
PRICE_SET = [0,5,10,15,20,25,30,35,40]
def extract_price(x):
    return PRICE_SET[int(x)]
data['Chosen Price'] = data['Actions'].map(lambda x: extract_price(x))

# %%
f, ax = plt.subplots(figsize=(15,7))
data['Chosen Price'].plot()

# %%
data = pkl.load(open('data/output/8350061_dynamic_True_rewards_dqn.pkl', "rb"))

# %%
data[-1]
# Out:
# {'NUM_EPISODES': 10000,
#  'EPSILON': 1,
#  'EPS_DECAY': 0.9998,
#  'LEARNING_RATE_': 0.001,
#  'GAMMA': 0.99,
#  'TARGET_UPDATE': 100,
#  'BATCH_SIZE': 32,
#  'TIME_STEP_SIZE': 3600,
#  'NUM_HOURS': 744,
#  'COMFORT_PENALTY': 1}

# %%
plt.figure()
plt.plot(data[:1000])
