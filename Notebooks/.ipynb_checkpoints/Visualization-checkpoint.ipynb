# %%
import pickle as pkl
import matplotlib.pyplot as plt
from matplotlib import style
import os 
os.chdir(os.path.dirname(os.getcwd()))
import pandas as pd
import pickle as pkl
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
style.use('ggplot')
# %matplotlib inline
import numpy as np
#import seaborn as sns

# %%
data = pkl.load(open('data/output/BaseProblem/Multi_Base_eval.pkl', "rb"))

# %%
data['Total Load'] = data['Total Load']*1000
data['Base Loads 1'] = data['Base Loads 1']*1000
data['Base Loads 2'] = data['Base Loads 2']*1000
data['Base Loads'] = data['Base Loads 1'] + data['Base Loads 2']

# %%
f, ax = plt.subplots(figsize=(15,7))
data['Base Loads'].plot()

# %%
data['above'] = (data['Total Load'] >= 5)*(data['Total Load']-5)

# %%
sum(data['above'])
# Out:
# 322.8404351794371

# %%
data['above'].mean()
# Out:
# 0.4333428660126672

# %%
data['Rewards'].sum()
# Out:
# -2362.740884185341

# %%
PRICE_SET = [10,20,30,40,50,60]
def extract_price(x):
    return PRICE_SET[int(x)]
data['Chosen Price'] = data['Actions'].map(lambda x: extract_price(x))

# %%
one_week = data.iloc[:,:]

# %%
f, ax = plt.subplots(4,1,figsize=(15,15))
one_week['Chosen Price'].plot(ax=ax[0])
one_week['Total Load'].plot(ax=ax[1])
one_week['Double Base'] = one_week['Base Loads']*2
one_week['Base Loads'].plot(ax=ax[1],c='g')
data_base.iloc[:,:]['Total Load'].plot(ax=ax[1],c='b', linestyle = 'dotted')
one_week['Inside Temperatures 1'].plot(ax=ax[2])
one_week['Inside Temperatures 2'].plot(ax=ax[2], c='b', linestyle = 'dotted')
one_week['Ambient Temperatures'].plot(ax=ax[3])

# %%
f, ax = plt.subplots(2,1,figsize=(15,15))
one_week['above'].plot(ax=ax[0])
data_base['above'].plot(ax=ax[0], c='b', linestyle = 'dotted')

# %%
sum(data['Total Load'] >= 5)
# Out:
# 403

# %%
data_base = pkl.load(open('data/output/BaseProblem/Multi_Basebase_eval.pkl', "rb"))

# %%
data_base['Total Load'] = data_base['Total Load']*1000
data_base['Base Loads 1'] = data_base['Base Loads 1']*1000
data_base['Base Loads 2'] = data_base['Base Loads 2']*1000
data_base['Base Loads'] = data_base['Base Loads 1'] + data_base['Base Loads 2']
data_base['above'] = (data_base['Total Load'] >= 5)*(data_base['Total Load']-5)

# %%
data_base['Rewards'].sum()
# Out:
# -2658.699720810283

# %%
sum(data_base['above'])
# Out:
# 494.8079501446397

# %%
data_base['above'].mean()
# Out:
# 0.6641717451605899

# %%
f, ax = plt.subplots(figsize=(15,7))
data_base['Total Load'].plot(ax=ax, linestyle='--')

# %%
sum(data_base['Total Load'] >= 5)
# Out:
# 385

# %%
data = pkl.load(open('data/output/BaseProblem/9543828_dynamic_True_rewards_dqn.pkl', "rb"))

# %%
data[-1]
# Out:
# {'NUM_EPISODES': 1000,
#  'EPSILON': 1,
#  'EPS_DECAY': 0.99997,
#  'LEARNING_RATE_': 0.00025,
#  'GAMMA': 0.99,
#  'TARGET_UPDATE': 10,
#  'BATCH_SIZE': 32,
#  'TIME_STEP_SIZE': 3600,
#  'NUM_HOURS': 744,
#  'COMFORT_PENALTY': 5,
#  'LOAD_PENALTY': 1000,
#  'PRICE_SENSITIVITY': 200,
#  'ZETA': 0.3}

# %%
plt.figure()
plt.plot(data[:-1])
rewards_df = pd.DataFrame()
rewards_df['reward'] = data[:-1]
moving_avg = rewards_df[:-1].rolling(window=10).mean()
plt.plot(moving_avg)

# %%
data_rms = pkl.load(open('data/output/8667145_dynamic_True_rewards_dqn.pkl', "rb"))

# %%
plt.figure()
plt.plot(data_rms[:-1])

# %% [markdown]
# # Buildings with RL agents

# %%
data = pkl.load(open('data/output/RLBuildings/9472229_dynamic_True_rewards_dqn.pkl', "rb"))

# %%
data[-1]
# Out:
# {'NUM_EPISODES': 1000,
#  'EPSILON': 1,
#  'EPS_DECAY': 0.99997,
#  'LEARNING_RATE_': 0.00025,
#  'GAMMA': 0.99,
#  'TARGET_UPDATE': 10,
#  'BATCH_SIZE': 32,
#  'TIME_STEP_SIZE': 3600,
#  'NUM_HOURS': 744,
#  'COMFORT_PENALTY': 5,
#  'LOAD_PENALTY': 1000,
#  'PRICE_SENSITIVITY': 200,
#  'ZETA': 0.3}

# %%
plt.figure()
plt.plot(data[:-1])
rewards_df = pd.DataFrame()
rewards_df['reward'] = data[:-1]
moving_avg = rewards_df[:-1].rolling(window=10).mean()
plt.plot(moving_avg)

# %% [markdown]
# # Evaluation on January

# %%
data = pkl.load(open("data/output/RLBuildings/Multi_RL_Zeta_january_0_3_eval.pkl", "rb"))

data['Total Load'] = data['Total Load']*1000
data['Base Loads 1'] = data['Base Loads 1']*1000
data['Base Loads 2'] = data['Base Loads 2']*1000
data['Base Loads'] = data['Base Loads 1'] + data['Base Loads 2']
data['Deviation from load limit'] = data['Total Load'] - 5
data['Date'] = pd.date_range(start='2014-01-01',end='2014-01-31-23:00:00', periods=len(data))
data['Day'] = data['Date'].dt.day

# %%
data['Above'] = (data['Total Load'] >= 5)*(data['Total Load']-5)
sum(data['Above'])
# Out:
# 433.05184453927455

# %%
data
# Out:
#      Inside Temperatures 1  Inside Temperatures 2  Base Loads 1  Base Loads 2  \
# 0                21.000000              21.000000      1.125480      1.115002
# 1                20.465719              19.950702      1.003822      0.927929
# 2                20.356919              19.450140      1.003643      0.890625
# 3                20.198313              19.199574      1.067182      0.818642
# 4                21.162442              19.449296      1.021891      0.946730
# ..                     ...                    ...           ...           ...
# 740              22.803741              20.282140      1.293548      1.387289
# 741              22.835035              20.221780      1.206444      1.367693
# 742              22.859724              20.485115      1.327446      1.079052
# 743              22.889053              20.731295      1.113228      1.077268
# 744              22.951823              20.991081      0.991770      1.038746
#
#      Actions 1  Actions 2  Ambient Temperatures  Actions   Rewards  \
# 0     0.000000   0.000000                 2.118      0.0  0.000000
# 1     0.449470   0.254955                 2.118      1.0 -0.021896
# 2     0.590363   0.424742                 2.147      1.0 -0.023772
# 3     0.559524   0.493816                 2.324      1.0 -0.024006
# 4     0.975084   0.672326                 2.344      0.0 -0.141992
# ..         ...        ...                   ...      ...       ...
# 740   1.000000   1.000000                -2.605      2.0 -2.062260
# 741   1.000000   0.863793                -2.735      5.0 -2.012470
# 742   1.000000   1.000000                -2.760      2.0 -2.166167
# 743   1.000000   0.999999                -2.714      2.0 -2.121379
# 744   1.000000   0.999986                -2.473      2.0 -2.056202
#
#      Total Load  Base Loads  Deviation from load limit  \
# 0      2.240482    2.240482                  -2.759518
# 1      3.649332    1.931751                  -1.350668
# 2      3.961960    1.894268                  -1.038040
# 3      4.000948    1.885824                  -0.999052
# 4      5.180644    1.968620                   0.180644
# ..          ...         ...                        ...
# 740    6.796444    2.680837                   1.796444
# 741    6.408422    2.574136                   1.408422
# 742    6.574136    2.406498                   1.574136
# 743    6.406496    2.190496                   1.406496
# 744    6.190468    2.030516                   1.190468
#
#                              Date  Day     Above
# 0   2014-01-01 00:00:00.000000000    1 -0.000000
# 1   2014-01-01 00:59:55.161290322    1 -0.000000
# 2   2014-01-01 01:59:50.322580645    1 -0.000000
# 3   2014-01-01 02:59:45.483870967    1 -0.000000
# 4   2014-01-01 03:59:40.645161290    1  0.180644
# ..                            ...  ...       ...
# 740 2014-01-31 19:00:19.354838709   31  1.796444
# 741 2014-01-31 20:00:14.516129032   31  1.408422
# 742 2014-01-31 21:00:09.677419355   31  1.574136
# 743 2014-01-31 22:00:04.838709677   31  1.406496
# 744 2014-01-31 23:00:00.000000000   31  1.190468
#
# [745 rows x 15 columns]

# %%
PRICE_SET = [10,20,30,40,50,60]
def extract_price(x):
    return PRICE_SET[int(x)]
data['Chosen Price'] = data['Actions'].map(lambda x: extract_price(x))

# %%
data['Daily Excess'] = data.groupby('Day')['Above'].sum()

# %%
data['Above'].mean()
# Out:
# 0.5812776436768783

# %%
data_base = pkl.load(open('data/output/RLBuildings/Multi_RL_Zeta0_january_base_eval.pkl', "rb"))

# %%
data_base['Total Load'] = data_base['Total Load']*1000
data_base['Base Loads 1'] = data_base['Base Loads 1']*1000
data_base['Base Loads 2'] = data_base['Base Loads 2']*1000
data_base['Base Loads'] = data_base['Base Loads 1'] + data_base['Base Loads 2']
data_base['Above'] = (data_base['Total Load'] >= 5)*(data_base['Total Load']-5)
data_base['Deviation from load limit'] = data_base['Total Load']-5

# %%
one_week = data.iloc[:,:]

# %%
f, ax = plt.subplots(4,1,figsize=(15,15))
one_week['Chosen Price'].plot(ax=ax[0])
one_week['Deviation from load limit'].plot(ax=ax[1])
one_week['Double Base'] = one_week['Base Loads']*2
#one_week['Base Loads'].plot(ax=ax[1],c='g')
data_base.iloc[:,:]['Deviation from load limit'].plot(ax=ax[1],c='b', linestyle = 'dotted')
one_week['Inside Temperatures 1'].plot(ax=ax[2])
one_week['Inside Temperatures 2'].plot(ax=ax[2], c='b', linestyle = 'dotted')
one_week['Ambient Temperatures'].plot(ax=ax[3])

# %%
sum(data_base['Above'])
# Out:
# 522.3680631684382

# %%
data_base['Above'].mean()
# Out:
# 0.7011651854609904

# %%
data_base['Date'] = pd.date_range(start='2014-01-01',end='2014-01-31-23:00:00', periods=len(data))
data_base['Day'] = data['Date'].dt.day
data_base['Daily Excess'] = data_base.groupby('Day')['Above'].sum()

# %%
data_base['Daily Excess']
# Out:
# 0           NaN
# 1      2.640445
# 2      1.895010
# 3      0.164418
# 4      0.701749
#          ...
# 740         NaN
# 741         NaN
# 742         NaN
# 743         NaN
# 744         NaN
# Name: Daily Excess, Length: 745, dtype: float64

# %%
N=len(data_base.dropna())
ind = np.arange(N)
f, axs = plt.subplots(1,figsize=(15,7), sharey=False)
axs.bar(ind, data_base['Daily Excess'].dropna(), color = 'b', width = 0.25)
axs.bar(ind+0.5, data['Daily Excess'].dropna(), color = 'r', width = 0.25)
axs.set_ylabel('Cost (€)')
axs.set_yticks(np.arange(0, 5, 1))
#for i, v in enumerate(cost_labels_values):
#    axs[0].text(i-0.15, 
#              v+0.2, 
#              v, 
#              fontsize=12)
axs.set_xticks(ind)
#axs.set_xticklabels(labels)
# Out:
# [<matplotlib.axis.XTick at 0x7f6ed2258d00>,
#  <matplotlib.axis.XTick at 0x7f6ed2258a60>,
#  <matplotlib.axis.XTick at 0x7f6ed22ae0d0>,
#  <matplotlib.axis.XTick at 0x7f6ed2630760>,
#  <matplotlib.axis.XTick at 0x7f6ed263b8b0>,
#  <matplotlib.axis.XTick at 0x7f6ed263be50>,
#  <matplotlib.axis.XTick at 0x7f6ed263f430>,
#  <matplotlib.axis.XTick at 0x7f6ed263f9d0>,
#  <matplotlib.axis.XTick at 0x7f6ed263ff70>,
#  <matplotlib.axis.XTick at 0x7f6ed2643550>,
#  <matplotlib.axis.XTick at 0x7f6ed2643af0>,
#  <matplotlib.axis.XTick at 0x7f6ed26480d0>,
#  <matplotlib.axis.XTick at 0x7f6ed2648670>,
#  <matplotlib.axis.XTick at 0x7f6ed2643640>,
#  <matplotlib.axis.XTick at 0x7f6ed263f100>,
#  <matplotlib.axis.XTick at 0x7f6ed2648220>,
#  <matplotlib.axis.XTick at 0x7f6ed2648dc0>,
#  <matplotlib.axis.XTick at 0x7f6ed264f3a0>,
#  <matplotlib.axis.XTick at 0x7f6ed264f940>,
#  <matplotlib.axis.XTick at 0x7f6ed264fee0>,
#  <matplotlib.axis.XTick at 0x7f6ed26534c0>,
#  <matplotlib.axis.XTick at 0x7f6ed2653a60>,
#  <matplotlib.axis.XTick at 0x7f6ed2658040>,
#  <matplotlib.axis.XTick at 0x7f6ed26530a0>,
#  <matplotlib.axis.XTick at 0x7f6ed26431c0>,
#  <matplotlib.axis.XTick at 0x7f6ed2648790>,
#  <matplotlib.axis.XTick at 0x7f6ed2658430>,
#  <matplotlib.axis.XTick at 0x7f6ed26589d0>,
#  <matplotlib.axis.XTick at 0x7f6ed2658f70>,
#  <matplotlib.axis.XTick at 0x7f6ed265f550>,
#  <matplotlib.axis.XTick at 0x7f6ed265faf0>]

# %% [markdown]
# # Evaluation on November/December
