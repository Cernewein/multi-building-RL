# %%
import pickle as pkl
import matplotlib.pyplot as plt
from matplotlib import style
import os 
os.chdir(os.path.dirname(os.getcwd()))
import pandas as pd
import pickle as pkl
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
style.use('ggplot')
# %matplotlib inline
import numpy as np
#import seaborn as sns

# %%
data = pkl.load(open('data/output/BaseProblem/Multi_Base_eval.pkl', "rb"))

# %%
data['Total Load'] = data['Total Load']*1000
data['Base Loads 1'] = data['Base Loads 1']*1000
data['Base Loads 2'] = data['Base Loads 2']*1000
data['Base Loads'] = data['Base Loads 1'] + data['Base Loads 2']

# %%
f, ax = plt.subplots(figsize=(15,7))
data['Base Loads'].plot()

# %%
data['above'] = (data['Total Load'] >= 5)*(data['Total Load']-5)

# %%
sum(data['above'])
# Out:
# 322.8404351794371

# %%
data['above'].mean()
# Out:
# 0.4333428660126672

# %%
data['Rewards'].sum()
# Out:
# -2362.740884185341

# %%
PRICE_SET = [10,20,30,40,50,60]
def extract_price(x):
    return PRICE_SET[int(x)]
data['Chosen Price'] = data['Actions'].map(lambda x: extract_price(x))

# %%
one_week = data.iloc[:,:]

# %%
f, ax = plt.subplots(4,1,figsize=(15,15))
one_week['Chosen Price'].plot(ax=ax[0])
one_week['Total Load'].plot(ax=ax[1])
one_week['Double Base'] = one_week['Base Loads']*2
one_week['Base Loads'].plot(ax=ax[1],c='g')
data_base.iloc[:,:]['Total Load'].plot(ax=ax[1],c='b', linestyle = 'dotted')
one_week['Inside Temperatures 1'].plot(ax=ax[2])
one_week['Inside Temperatures 2'].plot(ax=ax[2], c='b', linestyle = 'dotted')
one_week['Ambient Temperatures'].plot(ax=ax[3])

# %%
f, ax = plt.subplots(2,1,figsize=(15,15))
one_week['above'].plot(ax=ax[0])
data_base['above'].plot(ax=ax[0], c='b', linestyle = 'dotted')

# %%
sum(data['Total Load'] >= 5)
# Out:
# 403

# %%
data_base = pkl.load(open('data/output/BaseProblem/Multi_Basebase_eval.pkl', "rb"))

# %%
data_base['Total Load'] = data_base['Total Load']*1000
data_base['Base Loads 1'] = data_base['Base Loads 1']*1000
data_base['Base Loads 2'] = data_base['Base Loads 2']*1000
data_base['Base Loads'] = data_base['Base Loads 1'] + data_base['Base Loads 2']
data_base['above'] = (data_base['Total Load'] >= 5)*(data_base['Total Load']-5)

# %%
data_base['Rewards'].sum()
# Out:
# -2658.699720810283

# %%
sum(data_base['above'])
# Out:
# 494.8079501446397

# %%
data_base['above'].mean()
# Out:
# 0.6641717451605899

# %%
f, ax = plt.subplots(figsize=(15,7))
data_base['Total Load'].plot(ax=ax, linestyle='--')

# %%
sum(data_base['Total Load'] >= 5)
# Out:
# 385

# %%
data = pkl.load(open('data/output/BaseProblem/9543828_dynamic_True_rewards_dqn.pkl', "rb"))

# %%
data[-1]
# Out:
# {'NUM_EPISODES': 1000,
#  'EPSILON': 1,
#  'EPS_DECAY': 0.99997,
#  'LEARNING_RATE_': 0.00025,
#  'GAMMA': 0.99,
#  'TARGET_UPDATE': 10,
#  'BATCH_SIZE': 32,
#  'TIME_STEP_SIZE': 3600,
#  'NUM_HOURS': 744,
#  'COMFORT_PENALTY': 5,
#  'LOAD_PENALTY': 1000,
#  'PRICE_SENSITIVITY': 200,
#  'ZETA': 0.3}

# %%
plt.figure()
plt.plot(data[:-1])
rewards_df = pd.DataFrame()
rewards_df['reward'] = data[:-1]
moving_avg = rewards_df[:-1].rolling(window=10).mean()
plt.plot(moving_avg)

# %%
data_rms = pkl.load(open('data/output/8667145_dynamic_True_rewards_dqn.pkl', "rb"))

# %%
plt.figure()
plt.plot(data_rms[:-1])

# %% [markdown]
# # Buildings with RL agents

# %%
data = pkl.load(open('data/output/RLBuildings/9635680_dynamic_True_rewards_dqn.pkl', "rb"))

# %%
data[-1]
# Out:
# {'NUM_EPISODES': 1000,
#  'EPSILON': 1,
#  'EPS_DECAY': 0.99997,
#  'LEARNING_RATE_': 0.00025,
#  'GAMMA': 0.99,
#  'TARGET_UPDATE': 10,
#  'BATCH_SIZE': 32,
#  'TIME_STEP_SIZE': 3600,
#  'NUM_HOURS': 744,
#  'COMFORT_PENALTY': 5,
#  'LOAD_PENALTY': 1000,
#  'PRICE_SENSITIVITY': 200,
#  'ZETA': 0.3}

# %%
plt.figure()
plt.plot(data[:-1])
rewards_df = pd.DataFrame()
rewards_df['reward'] = data[:-1]
moving_avg = rewards_df[:-1].rolling(window=10).mean()
plt.plot(moving_avg)

# %% [markdown]
# # Evaluation on January

# %%
data = pkl.load(open("data/output/RLBuildings/Multi_RL_january_Zeta0.3_eval.pkl", "rb"))

data['Total Load'] = data['Total Load']*1000
data['Base Loads 1'] = data['Base Loads 1']*1000
data['Base Loads 2'] = data['Base Loads 2']*1000
data['Base Loads'] = data['Base Loads 1'] + data['Base Loads 2']
data['Deviation from load limit'] = data['Total Load'] - 5
data['Date'] = pd.date_range(start='2014-01-01',end='2014-01-31-23:00:00', periods=len(data))
data['Day'] = data['Date'].dt.day

# %%
data['Above'] = (data['Total Load'] >= 5)*(data['Total Load']-5)
sum(data['Above'])
# Out:
# 350.6407730918695

# %%
data
# Out:
#      Inside Temperatures 1  Inside Temperatures 2  Base Loads 1  Base Loads 2  \
# 0                21.000000              21.000000      1.125480      1.115002
# 1                21.604584              20.226017      1.003822      0.927929
# 2                21.434646              19.825367      1.003643      0.890625
# 3                21.437885              19.600476      1.067182      0.818642
# 4                21.437733              19.543267      1.021891      0.946730
# ..                     ...                    ...           ...           ...
# 740              19.593024              21.327395      1.293548      1.387289
# 741              19.515292              21.146104      1.206444      1.367693
# 742              19.471661              21.025421      1.327446      1.079052
# 743              19.443734              20.893091      1.113228      1.077268
# 744              19.413106              20.573525      0.991770      1.038746
#
#      Actions 1  Actions 2  Ambient Temperatures  Actions   Rewards  \
# 0     0.000000   0.000000                 2.118      0.0  0.000000
# 1     0.879607   0.358938                 2.118      0.0 -0.014153
# 2     0.606543   0.471943                 2.147      0.0 -0.012266
# 3     0.657377   0.516352                 2.324      0.0 -0.012725
# 4     0.655239   0.570737                 2.344      0.0 -0.013013
# ..         ...        ...                   ...      ...       ...
# 740   0.759616   0.773589                -2.605      5.0 -0.709529
# 741   0.829817   0.853013                -2.735      5.0 -0.841385
# 742   0.842729   0.873159                -2.760      5.0 -0.812244
# 743   0.844949   0.860802                -2.714      5.0 -0.762343
# 744   0.828478   0.762656                -2.473      5.0 -0.526442
#
#      Total Load  Base Loads  Deviation from load limit  \
# 0      2.240482    2.240482                  -2.759518
# 1      4.717572    1.931751                  -0.282428
# 2      4.088722    1.894268                  -0.911278
# 3      4.241727    1.885824                  -0.758273
# 4      4.337774    1.968620                  -0.662226
# ..          ...         ...                        ...
# 740    5.862854    2.680837                   0.862854
# 741    6.046497    2.574136                   1.046497
# 742    6.005911    2.406498                   1.005911
# 743    5.818001    2.190496                   0.818001
# 744    5.372764    2.030516                   0.372764
#
#                              Date  Day     Above
# 0   2014-01-01 00:00:00.000000000    1 -0.000000
# 1   2014-01-01 00:59:55.161290322    1 -0.000000
# 2   2014-01-01 01:59:50.322580645    1 -0.000000
# 3   2014-01-01 02:59:45.483870967    1 -0.000000
# 4   2014-01-01 03:59:40.645161290    1 -0.000000
# ..                            ...  ...       ...
# 740 2014-01-31 19:00:19.354838709   31  0.862854
# 741 2014-01-31 20:00:14.516129032   31  1.046497
# 742 2014-01-31 21:00:09.677419355   31  1.005911
# 743 2014-01-31 22:00:04.838709677   31  0.818001
# 744 2014-01-31 23:00:00.000000000   31  0.372764
#
# [745 rows x 15 columns]

# %%
PRICE_SET = [10,20,30,40,50,60]
def extract_price(x):
    return PRICE_SET[int(x)]
data['Chosen Price'] = data['Actions'].map(lambda x: extract_price(x))

# %%
data['Daily Excess'] = data.groupby('Day')['Above'].sum()

# %%
data['Above'].mean()
# Out:
# 0.4706587558280127

# %%
data_base = pkl.load(open('data/output/RLBuildings/Multi_RL_january_Zeta0.3base_10_eval.pkl', "rb"))

# %%
data_base['Total Load'] = data_base['Total Load']*1000
data_base['Base Loads 1'] = data_base['Base Loads 1']*1000
data_base['Base Loads 2'] = data_base['Base Loads 2']*1000
data_base['Base Loads'] = data_base['Base Loads 1'] + data_base['Base Loads 2']
data_base['Above'] = (data_base['Total Load'] >= 5)*(data_base['Total Load']-5)
data_base['Deviation from load limit'] = data_base['Total Load']-5

# %%
one_week = data.iloc[:,:]

# %%
f, ax = plt.subplots(4,1,figsize=(15,15))
one_week['Chosen Price'].plot(ax=ax[0])
one_week['Deviation from load limit'].plot(ax=ax[1])
one_week['Double Base'] = one_week['Base Loads']*2
#one_week['Base Loads'].plot(ax=ax[1],c='g')
data_base.iloc[:,:]['Deviation from load limit'].plot(ax=ax[1],c='b', linestyle = 'dotted')
one_week['Inside Temperatures 1'].plot(ax=ax[2])
one_week['Inside Temperatures 2'].plot(ax=ax[2], c='b', linestyle = 'dotted')
one_week['Ambient Temperatures'].plot(ax=ax[3])

# %%
sum(data_base['Above'])
# Out:
# 452.13186168131466

# %%
data_base['Above'].mean()
# Out:
# 0.6068884049413619

# %%
data_base['Date'] = pd.date_range(start='2014-01-01',end='2014-01-31-23:00:00', periods=len(data))
data_base['Day'] = data['Date'].dt.day
data_base['Daily Excess'] = data_base.groupby('Day')['Above'].sum()

# %%
data_base['Daily Excess']
# Out:
# 0           NaN
# 1      0.464095
# 2      1.331153
# 3      0.102105
# 4      0.203321
#          ...
# 740         NaN
# 741         NaN
# 742         NaN
# 743         NaN
# 744         NaN
# Name: Daily Excess, Length: 745, dtype: float64

# %%
N=len(data_base.dropna())
ind = np.arange(N)
f, axs = plt.subplots(1,figsize=(15,7), sharey=False)
axs.bar(ind - 0.25, data_base['Daily Excess'].dropna(), color = 'b', width = 0.25, label = 'Base with static price')
axs.bar(ind + 0.25, data['Daily Excess'].dropna(), color = 'r', width = 0.25, label = 'Dynamic prices with RL')
axs.set_ylabel('Daily load excess (kWh)')
axs.set_yticks(np.arange(0, 50, 10))
#for i, v in enumerate(cost_labels_values):
#    axs[0].text(i-0.15, 
#              v+0.2, 
#              v, 
#              fontsize=12)
axs.set_xticks(ind)
#axs.set_xticklabels(labels)
# Out:
# [<matplotlib.axis.XTick at 0x7f6ecb858ee0>,
#  <matplotlib.axis.XTick at 0x7f6ecb858f40>,
#  <matplotlib.axis.XTick at 0x7f6ecb8172e0>,
#  <matplotlib.axis.XTick at 0x7f6ecb773be0>,
#  <matplotlib.axis.XTick at 0x7f6ecb7781c0>,
#  <matplotlib.axis.XTick at 0x7f6ecb778760>,
#  <matplotlib.axis.XTick at 0x7f6ecb778d00>,
#  <matplotlib.axis.XTick at 0x7f6ecb77d2e0>,
#  <matplotlib.axis.XTick at 0x7f6ecb77d880>,
#  <matplotlib.axis.XTick at 0x7f6ecb7782b0>,
#  <matplotlib.axis.XTick at 0x7f6ecb768cd0>,
#  <matplotlib.axis.XTick at 0x7f6ecb77da30>,
#  <matplotlib.axis.XTick at 0x7f6ecb77dfd0>,
#  <matplotlib.axis.XTick at 0x7f6ecb7025b0>,
#  <matplotlib.axis.XTick at 0x7f6ecb702b50>,
#  <matplotlib.axis.XTick at 0x7f6ecb706130>,
#  <matplotlib.axis.XTick at 0x7f6ecb7066d0>,
#  <matplotlib.axis.XTick at 0x7f6ecb706c70>,
#  <matplotlib.axis.XTick at 0x7f6ecb70c250>,
#  <matplotlib.axis.XTick at 0x7f6ecb706250>,
#  <matplotlib.axis.XTick at 0x7f6ecb77dca0>,
#  <matplotlib.axis.XTick at 0x7f6ecb778ee0>,
#  <matplotlib.axis.XTick at 0x7f6ecb70c880>,
#  <matplotlib.axis.XTick at 0x7f6ecb70ce20>,
#  <matplotlib.axis.XTick at 0x7f6ecb711400>,
#  <matplotlib.axis.XTick at 0x7f6ecb7119a0>,
#  <matplotlib.axis.XTick at 0x7f6ecb711f40>,
#  <matplotlib.axis.XTick at 0x7f6ecb716520>,
#  <matplotlib.axis.XTick at 0x7f6ecb716ac0>,
#  <matplotlib.axis.XTick at 0x7f6ecb7d50a0>,
#  <matplotlib.axis.XTick at 0x7f6ecb70c4c0>]

# %% [markdown]
# # Evaluation on November/December

# %%
data = pkl.load(open("data/output/RLBuildings/Multi_RL_nov_dec_Zeta0.3_eval.pkl", "rb"))

data['Total Load'] = data['Total Load']*1000
data['Base Loads 1'] = data['Base Loads 1']*1000
data['Base Loads 2'] = data['Base Loads 2']*1000
data['Base Loads'] = data['Base Loads 1'] + data['Base Loads 2']
data['Deviation from load limit'] = data['Total Load'] - 5
data['Date'] = pd.date_range(start='2014-11-01',end='2014-12-31-23:00:00', periods=len(data))
data['Day'] = data['Date'].dt.day

# %%
data['Above'] = (data['Total Load'] >= 5)*(data['Total Load']-5)
sum(data['Above'])
# Out:
# 96.48817892866414

# %%
PRICE_SET = [10,20,30,40,50,60]
def extract_price(x):
    return PRICE_SET[int(x)]
data['Chosen Price'] = data['Actions'].map(lambda x: extract_price(x))

# %%
data['Daily Excess'] = data.groupby('Day')['Above'].sum()

# %%
data_base = pkl.load(open('data/output/RLBuildings/Multi_RL_nov_dec_Zeta0.3base_10_eval.pkl', "rb"))

# %%
data_base['Total Load'] = data_base['Total Load']*1000
data_base['Base Loads 1'] = data_base['Base Loads 1']*1000
data_base['Base Loads 2'] = data_base['Base Loads 2']*1000
data_base['Base Loads'] = data_base['Base Loads 1'] + data_base['Base Loads 2']
data_base['Above'] = (data_base['Total Load'] >= 5)*(data_base['Total Load']-5)
data_base['Deviation from load limit'] = data_base['Total Load']-5

# %%
sum(data_base['Above'])
# Out:
# 140.79023230520423

# %%
one_week = data.iloc[:,:]

# %%
f, ax = plt.subplots(4,1,figsize=(15,15))
one_week['Chosen Price'].plot(ax=ax[0])
one_week['Deviation from load limit'].plot(ax=ax[1])
one_week['Double Base'] = one_week['Base Loads']*2
#one_week['Base Loads'].plot(ax=ax[1],c='g')
data_base.iloc[:,:]['Deviation from load limit'].plot(ax=ax[1],c='b', linestyle = 'dotted')
one_week['Inside Temperatures 1'].plot(ax=ax[2])
one_week['Inside Temperatures 2'].plot(ax=ax[2], c='b', linestyle = 'dotted')
one_week['Ambient Temperatures'].plot(ax=ax[3])

# %%
data_base['Date'] = pd.date_range(start='2014-11-01',end='2014-12-31-23:00:00', periods=len(data))
data_base['Day'] = data['Date'].dt.day
data_base['Daily Excess'] = data_base.groupby('Day')['Above'].sum()

# %%
N=len(data_base.dropna())
ind = np.arange(N)
f, axs = plt.subplots(1,figsize=(15,7), sharey=False)
axs.bar(ind - 0.25, data_base['Daily Excess'].dropna(), color = 'b', width = 0.25, label = 'Base with static price')
axs.bar(ind + 0.25, data['Daily Excess'].dropna(), color = 'r', width = 0.25, label = 'Dynamic prices with RL')
axs.set_ylabel('Daily load excess (kWh)')
axs.set_yticks(np.arange(0, 50, 10))
#for i, v in enumerate(cost_labels_values):
#    axs[0].text(i-0.15, 
#              v+0.2, 
#              v, 
#              fontsize=12)
axs.set_xticks(ind)
#axs.set_xticklabels(labels)
# Out:
# [<matplotlib.axis.XTick at 0x7f6ecbaeafa0>,
#  <matplotlib.axis.XTick at 0x7f6ecbaeaee0>,
#  <matplotlib.axis.XTick at 0x7f6ecba8aaf0>,
#  <matplotlib.axis.XTick at 0x7f6ecb9d37c0>,
#  <matplotlib.axis.XTick at 0x7f6ecb9d3d60>,
#  <matplotlib.axis.XTick at 0x7f6ecb9d7340>,
#  <matplotlib.axis.XTick at 0x7f6ecb9d78e0>,
#  <matplotlib.axis.XTick at 0x7f6ecb9d7e80>,
#  <matplotlib.axis.XTick at 0x7f6ecb9dc460>,
#  <matplotlib.axis.XTick at 0x7f6ecb9dca00>,
#  <matplotlib.axis.XTick at 0x7f6ecb9d3ee0>,
#  <matplotlib.axis.XTick at 0x7f6ecb9caca0>,
#  <matplotlib.axis.XTick at 0x7f6ecb9dc580>,
#  <matplotlib.axis.XTick at 0x7f6ecb9dcfa0>,
#  <matplotlib.axis.XTick at 0x7f6ecb9e0580>,
#  <matplotlib.axis.XTick at 0x7f6ecb9e0b20>,
#  <matplotlib.axis.XTick at 0x7f6ecb9e7100>,
#  <matplotlib.axis.XTick at 0x7f6ecb9e76a0>,
#  <matplotlib.axis.XTick at 0x7f6ecb9e7c40>,
#  <matplotlib.axis.XTick at 0x7f6ecb9eb220>,
#  <matplotlib.axis.XTick at 0x7f6ecb9e7220>,
#  <matplotlib.axis.XTick at 0x7f6ecb9dcc70>,
#  <matplotlib.axis.XTick at 0x7f6ecb9d7b50>,
#  <matplotlib.axis.XTick at 0x7f6ecb9eb850>,
#  <matplotlib.axis.XTick at 0x7f6ecb9ebdf0>,
#  <matplotlib.axis.XTick at 0x7f6ecb9f23d0>,
#  <matplotlib.axis.XTick at 0x7f6ecb9f2970>,
#  <matplotlib.axis.XTick at 0x7f6ecb9f2f10>,
#  <matplotlib.axis.XTick at 0x7f6ecb9f74f0>,
#  <matplotlib.axis.XTick at 0x7f6ecb9f7a90>,
#  <matplotlib.axis.XTick at 0x7f6ecb9ca8b0>]
