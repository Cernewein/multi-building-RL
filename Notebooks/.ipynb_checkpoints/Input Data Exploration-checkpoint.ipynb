# %%
import pandas as pd
import numpy as np
import os
os.chdir(os.path.dirname(os.getcwd()))
import matplotlib.pyplot as plt
from matplotlib import style
import seaborn as sns
from statsmodels.tsa.seasonal import seasonal_decompose
sns.set('talk')
sns.set_style("ticks")
sns.set_color_codes()
# %matplotlib inline

# %% [markdown]
# # Base load data exploration

# %%
loads = pd.read_excel('data/environment/loads.xlsx',header=0)

# %%
loads
# Out:
#                      Date    Hours     DK1     DK2      DK string_date
# 0     2014-01-01 00:00:00  00 - 01  1838.0  1436.0  3274.0  01/01/2014
# 1     2014-01-01 00:00:00  01 - 02  1763.0  1408.0  3171.0  01/01/2014
# 2     2014-01-01 00:00:00  02 - 03  1698.0  1345.0  3043.0  01/01/2014
# 3     2014-01-01 00:00:00  03 - 04  1663.0  1300.0  2963.0  01/01/2014
# 4     2014-01-01 00:00:00  04 - 05  1604.0  1275.0  2879.0  01/01/2014
# ...                   ...      ...     ...     ...     ...         ...
# 8756           31-12-2014  19 - 20  2267.0  1783.0  4050.0  31-12-2014
# 8757           31-12-2014  20 - 21  2070.0  1617.0  3687.0  31-12-2014
# 8758           31-12-2014  21 - 22  2019.0  1565.0  3584.0  31-12-2014
# 8759           31-12-2014  22 - 23  1962.0  1503.0  3465.0  31-12-2014
# 8760           31-12-2014  23 - 00  1880.0  1449.0  3329.0  31-12-2014
#
# [8761 rows x 6 columns]

# %%
loads = loads.rename(columns={'Unnamed: 0':'Date'})
loads['hour'] = loads['Hours'].map(lambda x: x.split('-')[0].strip())

# %%
def extract_date(x,column):
    if column == 1:
        try: 
            return x.split('/')[1]
        except: 
            return x.split('-')[1]
    else:
        try: 
            x.split('/')[1]
            return x.split('/')[0]
        except: 
            return x.split('-')[0]
loads['year']='2014'
loads['month']=loads['string_date'].map(lambda x: extract_date(x,1))
loads['day']=loads['string_date'].map(lambda x: extract_date(x,0))

# %%
loads
# Out:
#                      Date    Hours     DK1     DK2      DK string_date hour  \
# 0     2014-01-01 00:00:00  00 - 01  1838.0  1436.0  3274.0  01/01/2014   00
# 1     2014-01-01 00:00:00  01 - 02  1763.0  1408.0  3171.0  01/01/2014   01
# 2     2014-01-01 00:00:00  02 - 03  1698.0  1345.0  3043.0  01/01/2014   02
# 3     2014-01-01 00:00:00  03 - 04  1663.0  1300.0  2963.0  01/01/2014   03
# 4     2014-01-01 00:00:00  04 - 05  1604.0  1275.0  2879.0  01/01/2014   04
# ...                   ...      ...     ...     ...     ...         ...  ...
# 8756           31-12-2014  19 - 20  2267.0  1783.0  4050.0  31-12-2014   19
# 8757           31-12-2014  20 - 21  2070.0  1617.0  3687.0  31-12-2014   20
# 8758           31-12-2014  21 - 22  2019.0  1565.0  3584.0  31-12-2014   21
# 8759           31-12-2014  22 - 23  1962.0  1503.0  3465.0  31-12-2014   22
# 8760           31-12-2014  23 - 00  1880.0  1449.0  3329.0  31-12-2014   23
#
#       year month day
# 0     2014    01  01
# 1     2014    01  01
# 2     2014    01  01
# 3     2014    01  01
# 4     2014    01  01
# ...    ...   ...  ..
# 8756  2014    12  31
# 8757  2014    12  31
# 8758  2014    12  31
# 8759  2014    12  31
# 8760  2014    12  31
#
# [8761 rows x 10 columns]

# %%
loads['date'] = pd.to_datetime(loads[['year','month','day','hour']])
loads
# Out:
#                      Date    Hours     DK1     DK2      DK string_date hour  \
# 0     2014-01-01 00:00:00  00 - 01  1838.0  1436.0  3274.0  01/01/2014   00
# 1     2014-01-01 00:00:00  01 - 02  1763.0  1408.0  3171.0  01/01/2014   01
# 2     2014-01-01 00:00:00  02 - 03  1698.0  1345.0  3043.0  01/01/2014   02
# 3     2014-01-01 00:00:00  03 - 04  1663.0  1300.0  2963.0  01/01/2014   03
# 4     2014-01-01 00:00:00  04 - 05  1604.0  1275.0  2879.0  01/01/2014   04
# ...                   ...      ...     ...     ...     ...         ...  ...
# 8756           31-12-2014  19 - 20  2267.0  1783.0  4050.0  31-12-2014   19
# 8757           31-12-2014  20 - 21  2070.0  1617.0  3687.0  31-12-2014   20
# 8758           31-12-2014  21 - 22  2019.0  1565.0  3584.0  31-12-2014   21
# 8759           31-12-2014  22 - 23  1962.0  1503.0  3465.0  31-12-2014   22
# 8760           31-12-2014  23 - 00  1880.0  1449.0  3329.0  31-12-2014   23
#
#       year month day                date
# 0     2014    01  01 2014-01-01 00:00:00
# 1     2014    01  01 2014-01-01 01:00:00
# 2     2014    01  01 2014-01-01 02:00:00
# 3     2014    01  01 2014-01-01 03:00:00
# 4     2014    01  01 2014-01-01 04:00:00
# ...    ...   ...  ..                 ...
# 8756  2014    12  31 2014-12-31 19:00:00
# 8757  2014    12  31 2014-12-31 20:00:00
# 8758  2014    12  31 2014-12-31 21:00:00
# 8759  2014    12  31 2014-12-31 22:00:00
# 8760  2014    12  31 2014-12-31 23:00:00
#
# [8761 rows x 11 columns]

# %%
loads = loads.fillna(method='ffill')

# %%
print(sum(loads['DK'])/3448*1000)
print(sum(loads['DK1'])/3448*1000)
print(sum(loads['DK2'])/3448*1000)
# Out:
# 9717866.009280743
# 5841504.350348027
# 3876332.0765661253

# %%
loads['DK2_scaled'] = loads['DK2']/(sum(loads['DK2'])/9244)/1000

# %%
start = pd.to_datetime('2014-11-01',infer_datetime_format=True)
end = pd.to_datetime('2014-12-31',infer_datetime_format=True)
loads.loc[loads['date'] >= start,'DK2_scaled']
# Out:
# 7297    0.000819
# 7298    0.000768
# 7299    0.000739
# 7300    0.000728
# 7301    0.000728
#           ...
# 8756    0.001233
# 8757    0.001118
# 8758    0.001082
# 8759    0.001040
# 8760    0.001002
# Name: DK2_scaled, Length: 1464, dtype: float64

# %%
loads['DK2_scaled'].to_csv('2014_DK2_scaled_loads.csv')

# %%
loads['DK2_scaled'] = loads['DK2_scaled']*1000
loads['DK2_scaled_1'] = loads['DK2_scaled'] + np.random.normal(loc=0.0, scale=0.075, size=len(loads))
loads['DK2_scaled_2'] = loads['DK2_scaled'] + np.random.normal(loc=0.0, scale=0.075, size=len(loads))

# %%
start = pd.to_datetime('2014-01-01',infer_datetime_format=True)
end = pd.to_datetime('2014-01-31',infer_datetime_format=True)
jan = loads.loc[(loads['date'] <= end) & (loads['date'] >= start)]
jan.index = jan['date']
#jan['DK2_scaled'] *= 1000

# %%
f, ax = plt.subplots(figsize=(15,5))

plt.ylabel('Load (kW)')
jan['DK2_scaled'].plot(ax=ax)
jan['DK2_scaled_1'].plot(ax=ax)
jan['DK2_scaled_2'].plot(ax=ax)

ax.legend(['Observed','House 1', 'House 2'])
plt.xlabel('')
#plt.savefig('data/output/Input_base_loads.png',bbox_inches='tight')
# Out:
# Text(0.5, 0, '')

# %%
result.seasonal.index
# Out:
# DatetimeIndex(['2014-01-01 00:00:00', '2014-01-01 01:00:00',
#                '2014-01-01 02:00:00', '2014-01-01 03:00:00',
#                '2014-01-01 04:00:00', '2014-01-01 05:00:00',
#                '2014-01-01 06:00:00', '2014-01-01 07:00:00',
#                '2014-01-01 08:00:00', '2014-01-01 09:00:00',
#                ...
#                '2014-01-30 15:00:00', '2014-01-30 16:00:00',
#                '2014-01-30 17:00:00', '2014-01-30 18:00:00',
#                '2014-01-30 19:00:00', '2014-01-30 20:00:00',
#                '2014-01-30 21:00:00', '2014-01-30 22:00:00',
#                '2014-01-30 23:00:00', '2014-01-31 00:00:00'],
#               dtype='datetime64[ns]', name='date', length=721, freq=None)

# %%
result = seasonal_decompose(jan['DK2_scaled'], model='additive')

# %%
resid = result.observed - result.seasonal - result.trend

# %%
result.resid#.dropna()
# Out:
# date
# 2014-01-01 00:00:00   NaN
# 2014-01-01 01:00:00   NaN
# 2014-01-01 02:00:00   NaN
# 2014-01-01 03:00:00   NaN
# 2014-01-01 04:00:00   NaN
#                        ..
# 2014-01-30 20:00:00   NaN
# 2014-01-30 21:00:00   NaN
# 2014-01-30 22:00:00   NaN
# 2014-01-30 23:00:00   NaN
# 2014-01-31 00:00:00   NaN
# Name: resid, Length: 721, dtype: float64

# %%
result.trend.iloc[24:]
# Out:
# date
# 2014-01-02 00:00:00    1.148965
# 2014-01-02 01:00:00    1.161155
# 2014-01-02 02:00:00    1.172192
# 2014-01-02 03:00:00    1.182696
# 2014-01-02 04:00:00    1.193157
#                          ...
# 2014-01-30 20:00:00         NaN
# 2014-01-30 21:00:00         NaN
# 2014-01-30 22:00:00         NaN
# 2014-01-30 23:00:00         NaN
# 2014-01-31 00:00:00         NaN
# Name: trend, Length: 697, dtype: float64

# %%
result.observed
# Out:
# date
# 2014-01-01 00:00:00    0.993176
# 2014-01-01 01:00:00    0.973810
# 2014-01-01 02:00:00    0.930238
# 2014-01-01 03:00:00    0.899115
# 2014-01-01 04:00:00    0.881824
#                          ...
# 2014-01-30 20:00:00    1.457949
# 2014-01-30 21:00:00    1.374262
# 2014-01-30 22:00:00    1.246311
# 2014-01-30 23:00:00    1.128043
# 2014-01-31 00:00:00    1.047123
# Name: DK2_scaled, Length: 721, dtype: float64

# %%
f, ax = plt.subplots(4,1,figsize=(25,15),sharex=True)
ax[0].plot(result.observed.index,result.observed)
ax[0].set_ylabel('Observed')
ax[1].plot(result.observed.index,result.seasonal)
ax[1].set_ylabel('Seasonal')
ax[2].plot(result.observed.index,result.trend)
ax[2].set_ylabel('Trend')
ax[3].scatter(result.observed.index,result.resid)
#ax[3].xlim(result.observed.index[0], result.observed.index[-1])
ax[3].set_ylabel('Residual')

plt.savefig('data/output/jan_load.png',bbox_inches='tight')

# %%
selected = loads.loc[(loads['month'] == '01') | (loads['month'] == '11') | (loads['month'] == '12'),:]
months = {
    '01':'January',
    '11': 'November',
    '12': 'December'
}

def extract_months(x):
    return months[x]

selected['Month'] = selected['month'].map(lambda x: extract_months(x))
# Out:
# <ipython-input-13-9d01621dc04d>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected['Month'] = selected['month'].map(lambda x: extract_months(x))

# %%
selected
# Out:
#                      Date    Hours     DK1     DK2      DK string_date hour  \
# 0     2014-01-01 00:00:00  00 - 01  1838.0  1436.0  3274.0  01/01/2014   00
# 1     2014-01-01 00:00:00  01 - 02  1763.0  1408.0  3171.0  01/01/2014   01
# 2     2014-01-01 00:00:00  02 - 03  1698.0  1345.0  3043.0  01/01/2014   02
# 3     2014-01-01 00:00:00  03 - 04  1663.0  1300.0  2963.0  01/01/2014   03
# 4     2014-01-01 00:00:00  04 - 05  1604.0  1275.0  2879.0  01/01/2014   04
# ...                   ...      ...     ...     ...     ...         ...  ...
# 8756           31-12-2014  19 - 20  2267.0  1783.0  4050.0  31-12-2014   19
# 8757           31-12-2014  20 - 21  2070.0  1617.0  3687.0  31-12-2014   20
# 8758           31-12-2014  21 - 22  2019.0  1565.0  3584.0  31-12-2014   21
# 8759           31-12-2014  22 - 23  1962.0  1503.0  3465.0  31-12-2014   22
# 8760           31-12-2014  23 - 00  1880.0  1449.0  3329.0  31-12-2014   23
#
#       year month day                date  DK2_scaled  DK2_scaled_1  \
# 0     2014    01  01 2014-01-01 00:00:00    0.993176      1.001887
# 1     2014    01  01 2014-01-01 01:00:00    0.973810      1.047699
# 2     2014    01  01 2014-01-01 02:00:00    0.930238      0.966571
# 3     2014    01  01 2014-01-01 03:00:00    0.899115      0.860536
# 4     2014    01  01 2014-01-01 04:00:00    0.881824      0.832382
# ...    ...   ...  ..                 ...         ...           ...
# 8756  2014    12  31 2014-12-31 19:00:00    1.233170      1.147254
# 8757  2014    12  31 2014-12-31 20:00:00    1.118360      1.023747
# 8758  2014    12  31 2014-12-31 21:00:00    1.082396      0.995819
# 8759  2014    12  31 2014-12-31 22:00:00    1.039515      1.070010
# 8760  2014    12  31 2014-12-31 23:00:00    1.002167      0.998331
#
#       DK2_scaled_2     Month
# 0         0.859545   January
# 1         1.024793   January
# 2         0.908167   January
# 3         0.903386   January
# 4         1.037649   January
# ...            ...       ...
# 8756      1.147048  December
# 8757      1.144739  December
# 8758      1.023384  December
# 8759      1.087878  December
# 8760      0.948595  December
#
# [2208 rows x 15 columns]

# %%
f, ax = plt.subplots(1,1,figsize=(15,5))

sns.boxplot(x=selected["Month"], y=selected["DK2_scaled"], ax=ax)

ax.set_xlabel('')
ax.set_ylabel('Load (kW)')
plt.savefig('data/output/Load_Boxplot.png',bbox_inches='tight')

# %%
f, ax = plt.subplots(figsize=(15,5))

plt.ylabel('Load (kW)')
jan['DK2_scaled'].plot(ax=ax)
#jan['DK2_scaled_2'].plot(ax=ax)

ax.legend(['House 1'])
plt.xlabel('')
#plt.savefig('data/output/Input_base_loads.png',bbox_inches='tight')
# Out:
# Text(0.5, 0, '')

# %% [markdown]
# # Definition of ToU prices for benchmarking

# %%
time_of_use_prices = pd.DataFrame()
time_of_use_prices['date'] = loads['date']
time_of_use_prices['hour'] = loads['hour']

# %%
price_mapping_dict = {
    '00':20,
    '01':20,
    '02':20,
    '03':20,
    '04':20,
    '05':20,
    '06':20,
    '07':30,
    '08':30,
    '09':30,
    '10':30,
    '11':30,
    '12':30,
    '13':30,
    '14':30,
    '15':40,
    '16':40,
    '17':40,
    '18':40,
    '19':30,
    '20':30,
    '21':30,
    '22':20,
    '23':20,
}

def price_mapping(x):
    return price_mapping_dict[x]

time_of_use_prices['price'] = time_of_use_prices['hour'].map(lambda x: price_mapping(x))

# %%
time_of_use_prices.loc[(loads['date'] <= end) & (loads['date'] >= start)]
# Out:
#                   date hour  price
# 48 2014-01-03 00:00:00   00     20
# 49 2014-01-03 01:00:00   01     20
# 50 2014-01-03 02:00:00   02     20
# 51 2014-01-03 03:00:00   03     20
# 52 2014-01-03 04:00:00   04     20
# 53 2014-01-03 05:00:00   05     20
# 54 2014-01-03 06:00:00   06     20
# 55 2014-01-03 07:00:00   07     30
# 56 2014-01-03 08:00:00   08     30
# 57 2014-01-03 09:00:00   09     30
# 58 2014-01-03 10:00:00   10     30
# 59 2014-01-03 11:00:00   11     30
# 60 2014-01-03 12:00:00   12     30
# 61 2014-01-03 13:00:00   13     30
# 62 2014-01-03 14:00:00   14     30
# 63 2014-01-03 15:00:00   15     40
# 64 2014-01-03 16:00:00   16     40
# 65 2014-01-03 17:00:00   17     40
# 66 2014-01-03 18:00:00   18     40
# 67 2014-01-03 19:00:00   19     30
# 68 2014-01-03 20:00:00   20     30
# 69 2014-01-03 21:00:00   21     30
# 70 2014-01-03 22:00:00   22     20
# 71 2014-01-03 23:00:00   23     20
# 72 2014-01-04 00:00:00   00     20

# %%
time_of_use_prices['price'].to_csv('2014_ToU_prices.csv')

# %%
f, ax = plt.subplots(figsize=(15,5))
time_of_use_prices
# Out:
#                     date hour  price
# 0    2014-01-01 00:00:00   00     20
# 1    2014-01-01 01:00:00   01     20
# 2    2014-01-01 02:00:00   02     20
# 3    2014-01-01 03:00:00   03     20
# 4    2014-01-01 04:00:00   04     20
# ...                  ...  ...    ...
# 8756 2014-12-31 19:00:00   19     30
# 8757 2014-12-31 20:00:00   20     30
# 8758 2014-12-31 21:00:00   21     30
# 8759 2014-12-31 22:00:00   22     20
# 8760 2014-12-31 23:00:00   23     20
#
# [8761 rows x 3 columns]
